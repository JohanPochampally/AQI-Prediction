# %% [markdown]
# # Data Preprocessing

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
df= pd.read_csv('/content/gdrive/Shareddrives/Projects - Nihal, Arya, Johan/Projects - Nihal, Arya, Johan/Mini Project/city_day.csv')
df
# Out:
#                 City        Date  PM2.5   PM10     NO    NO2    NOx    NH3  \
# 0          Ahmedabad  2015-01-01    NaN    NaN   0.92  18.22  17.15    NaN
# 1          Ahmedabad  2015-01-02    NaN    NaN   0.97  15.69  16.46    NaN
# 2          Ahmedabad  2015-01-03    NaN    NaN  17.40  19.30  29.70    NaN
# 3          Ahmedabad  2015-01-04    NaN    NaN   1.70  18.48  17.97    NaN
# 4          Ahmedabad  2015-01-05    NaN    NaN  22.10  21.42  37.76    NaN
# ...              ...         ...    ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam  2020-06-27  15.02  50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38  74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91  65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64  49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01  15.00  66.00   0.40  26.85  14.05   5.20
#
# ...

# %%
df.describe()
# Out:
#               PM2.5          PM10            NO           NO2           NOx  \
# count  24933.000000  18391.000000  25949.000000  25946.000000  25346.000000
# mean      67.450578    118.127103     17.574730     28.560659     32.309123
# std       64.661449     90.605110     22.785846     24.474746     31.646011
# min        0.040000      0.010000      0.020000      0.010000      0.000000
# 25%       28.820000     56.255000      5.630000     11.750000     12.820000
# 50%       48.570000     95.680000      9.890000     21.690000     23.520000
# 75%       80.590000    149.745000     19.950000     37.620000     40.127500
# max      949.990000   1000.000000    390.680000    362.210000    467.630000
#
#                 NH3            CO           SO2            O3       Benzene  \
# count  19203.000000  27472.000000  25677.000000  25509.000000  23908.000000
# mean      23.483476      2.248598     14.531977     34.491430      3.280840
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29531 entries, 0 to 29530
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        29531 non-null  object
#  1   Date        29531 non-null  object
#  2   PM2.5       24933 non-null  float64
#  3   PM10        18391 non-null  float64
#  4   NO          25949 non-null  float64
#  5   NO2         25946 non-null  float64
#  6   NOx         25346 non-null  float64
#  7   NH3         19203 non-null  float64
#  8   CO          27472 non-null  float64
#  9   SO2         25677 non-null  float64
#  10  O3          25509 non-null  float64
#  11  Benzene     23908 non-null  float64
#  12  Toluene     21490 non-null  float64
#  13  Xylene      11422 non-null  float64
#  14  AQI         24850 non-null  float64
#  15  AQI_Bucket  24850 non-null  object
# dtypes: float64(13), object(3)
# memory usage: 3.6+ MB

# %%
df.isna().sum()
# Out:
# City              0
# Date              0
# PM2.5          4598
# PM10          11140
# NO             3582
# NO2            3585
# NOx            4185
# NH3           10328
# CO             2059
# SO2            3854
# O3             4022
# Benzene        5623
# Toluene        8041
# Xylene        18109
# AQI            4681
# AQI_Bucket     4681
# dtype: int64

# %%
df.shape
# Out:
# (29531, 16)

# %%
df.size
# Out:
# 472496

# %%
df_copy = df.copy()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df_copy.corr(),cbar=True,annot=True,cmap='Blues')

# %%
plt.figure(figsize=(10,10))
plt.scatter(x='PM2.5',y='AQI',data=df_copy)
plt.xlabel('PM2.5')
plt.ylabel('AQI')
# Out:
# Text(0, 0.5, 'AQI')

# %%
sns.pairplot(df_copy)

# %%
df_copy=df_copy.drop(['City'],axis=1)
df_copy=df_copy.drop(['Date'],axis=1)

# %%
df_copy = df_copy[df_copy['AQI'].notna()]

# %%
df_copy.head(30)
# Out:
#      PM2.5  PM10     NO    NO2     NOx  NH3     CO     SO2      O3  Benzene  \
# 28   83.13   NaN   6.93  28.71   33.72  NaN   6.93   49.52   59.76     0.02
# 29   79.84   NaN  13.85  28.68   41.08  NaN  13.85   48.49   97.07     0.04
# 30   94.52   NaN  24.39  32.66   52.61  NaN  24.39   67.39  111.33     0.24
# 31  135.99   NaN  43.48  42.08   84.57  NaN  43.48   75.23  102.70     0.40
# 32  178.33   NaN  54.56  35.31   72.80  NaN  54.56   55.04  107.38     0.46
# 33  139.70   NaN  30.61  28.40   56.73  NaN  30.61   33.79   73.60     0.17
# 34   80.65   NaN   2.37  22.83   24.00  NaN   2.37   25.73   47.30     0.00
# 35   58.36   NaN   2.60  21.39   23.31  NaN   2.60   32.66   53.54     0.00
# 36   79.29   NaN   1.16  26.94   26.83  NaN   1.16   67.41   59.30     0.00
# 37   88.70   NaN   7.29  31.32   37.73  NaN   7.29   80.09   44.76     0.00
# 38   74.28   NaN   8.92  27.30   33.42  NaN   8.92   54.28   47.42     0.00
# ...

# %%
df_copy.isna().sum()
# Out:
# PM2.5           678
# PM10           7086
# NO              387
# NO2             391
# NOx            1857
# NH3            6536
# CO              445
# SO2             605
# O3              807
# Benzene        3535
# Toluene        5826
# Xylene        15372
# AQI               0
# AQI_Bucket        0
# dtype: int64

# %%
df_copy.size
# Out:
# 347900

# %%
df_copy.shape
# Out:
# (24850, 14)

# %%
df_copy['AQI_Bucket'].fillna(df_copy['AQI_Bucket'].mode(), inplace = True)

# %%
df_copy['Benzene'].fillna(df_copy['Benzene'].median(), inplace = True)
df_copy['PM2.5'].fillna(df_copy['PM2.5'].median(), inplace = True)
df_copy['PM10'].fillna(df_copy['PM10'].median(), inplace = True)
df_copy['NO'].fillna(df_copy['NO'].median(), inplace = True)
df_copy['NO2'].fillna(df_copy['NO2'].median(), inplace = True)
df_copy['NOx'].fillna(df_copy['NOx'].median(), inplace = True)
df_copy['NH3'].fillna(df_copy['NH3'].median(), inplace = True)
df_copy['CO'].fillna(df_copy['CO'].median(), inplace = True)
df_copy['SO2'].fillna(df_copy['SO2'].median(), inplace = True)
df_copy['O3'].fillna(df_copy['O3'].median(), inplace = True)
df_copy['Toluene'].fillna(df_copy['Toluene'].median(), inplace = True)
df_copy['Xylene'].fillna(df_copy['Xylene'].median(), inplace = True)

# %%
df0 = df_copy.copy()

# %%
index_names = df0[ df0['AQI'] > 500 ].index
  
# drop these row indexes
# from dataFrame
df0.drop(index_names, inplace = True)
  
df0.size
# Out:
# 340298

# %%
plt.figure(figsize=(10,10))
plt.scatter(x='PM2.5',y='AQI',data=df0)
plt.xlabel('PM2.5')
plt.ylabel('AQI')
# Out:
# Text(0, 0.5, 'AQI')

# %%
X = df0.iloc[:,:-2].values
y = df0.iloc[:,-2].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 1)

# %% [markdown]
# # Multiple Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
regressor = LinearRegression()

# %%
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_prediction =  regressor.predict(X_test)
print(y_prediction)
# Out:
# [ 86.25787667 174.02033172 132.27223639 ... 271.97234475 134.45829107
#  114.56730015]

# %%
# importing r2_score module
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
# predicting the accuracy score
score=r2_score(y_test,y_prediction)
print('r2 socre is',score)
print('mean_sqrd_error is=',mean_squared_error(y_test,y_prediction))
print('root_mean_squared error of is=',np.sqrt(mean_squared_error(y_test,y_prediction)))
print('MAE:', mean_absolute_error(y_test, y_prediction))
# Out:
# r2 socre is 0.8147610397628889
# mean_sqrd_error is= 1958.4797486783189
# root_mean_squared error of is= 44.25471442319246
# MAE: 27.982489541019206

# %%
regressor.coef_
# Out:
# array([ 1.20830594,  0.26471356, -0.15819973,  0.0951505 ,  0.16987265,
#        -0.06612954,  7.9961124 ,  0.65798187,  0.20000674, -0.0551629 ,
#         0.01279187, -0.39926625])

# %%
regressor.intercept_
# Out:
# 14.024055067190261

# %%
sns.distplot(y_test-y_prediction)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.scatter(y_test,y_prediction)

# %% [markdown]
# # Decision Tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtr = DecisionTreeRegressor(random_state=1)

# %%
dtr.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=1)

# %%
dtr_prediction = dtr.predict(X_test)

# %%
dtr_prediction
# Out:
# array([ 96., 372., 121., ..., 334., 111., 106.])

# %%
dtr_score=r2_score(y_test,dtr_prediction)
print('r2 socre is',dtr_score)
print('mean_sqrd_error is=',mean_squared_error(y_test,dtr_prediction))
print('root_mean_squared error of is=',np.sqrt(mean_squared_error(y_test,dtr_prediction)))
print('MAE:', mean_absolute_error(y_test, dtr_prediction))
# Out:
# r2 socre is 0.8459387041169089
# mean_sqrd_error is= 1628.8470182296144
# root_mean_squared error of is= 40.358976922484224
# MAE: 25.65413077712543

# %% [markdown]
# # Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr = RandomForestRegressor(random_state = 0)

# %%
rfr.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=0)

# %%
rfr_pred = rfr.predict(X_test)

# %%
print(rfr_pred)
# Out:
# [ 95.69 219.34 121.81 ... 324.3  110.58  89.79]

# %%
rfr_score = r2_score(y_test,rfr_pred)

# %%
print('r2 socre is',rfr_score)
print('mean_sqrd_error is=',mean_squared_error(y_test,rfr_pred))
print('root_mean_squared error of is=',np.sqrt(mean_squared_error(y_test,rfr_pred)))
print('MAE:', mean_absolute_error(y_test, rfr_pred))
# Out:
# r2 socre is 0.9187176600437296
# mean_sqrd_error is= 859.3754603555038
# root_mean_squared error of is= 29.31510635074524
# MAE: 18.131406631165216

# %% [markdown]
# # Support Vector Regression

# %%
from sklearn.svm import SVR

# %%
svr = SVR(kernel = 'rbf')

# %%
svr.fit(X_train, y_train)
# Out:
# SVR()

# %%
svr_pred = svr.predict(X_test)

# %%
print(svr_pred)
# Out:
# [ 92.97583409  95.51700799 124.51930774 ... 308.16091151 113.71195387
#  100.32015001]

# %%
svr_score = r2_score(y_test,svr_pred)

# %%
print('r2 socre is',svr_score)
print('mean_sqrd_error is=',mean_squared_error(y_test,svr_pred))
print('root_mean_squared error of is=',np.sqrt(mean_squared_error(y_test,svr_pred)))
print('MAE:', mean_absolute_error(y_test, svr_pred))
# Out:
# r2 socre is 0.7880001614239405
# mean_sqrd_error is= 2241.4150351676612
# root_mean_squared error of is= 47.343584942077015
# MAE: 27.528666144018427

# %% [markdown]
# # Model Summary

# %%
models_summary = pd.DataFrame([],columns=['model name', 'prediction score','mean absolute error'])

# %%
models_summary = models_summary.append({
    'model name': regressor.__class__.__name__,
    'prediction score': score,
    'mean absolute error' : mean_absolute_error(y_test, y_prediction)
}, ignore_index=True)

# %%
models_summary = models_summary.append({
    'model name': dtr.__class__.__name__,
    'prediction score': dtr_score,
    'mean absolute error' : mean_absolute_error(y_test, dtr_prediction)
}, ignore_index=True)

# %%
models_summary = models_summary.append({
    'model name': rfr.__class__.__name__,
    'prediction score': rfr_score,
    'mean absolute error' : mean_absolute_error(y_test, rfr_pred)
}, ignore_index=True)

# %%
models_summary = models_summary.append({
    'model name': svr.__class__.__name__,
    'prediction score': svr_score,
    'mean absolute error' : mean_absolute_error(y_test, svr_pred)
}, ignore_index=True)

# %%
models_summary
# Out:
#               model name  prediction score  mean absolute error
# 0       LinearRegression          0.814761            27.982490
# 1  DecisionTreeRegressor          0.845939            25.654131
# 2  RandomForestRegressor          0.918718            18.131407
# 3                    SVR          0.788000            27.528666
